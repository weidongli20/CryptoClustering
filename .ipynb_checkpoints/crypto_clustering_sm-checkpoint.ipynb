# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import requests
import pandas as pd
import matplotlib.pyplot as plt
#import hvplot.pandas
#import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"

# %%
# Create a DataFrame 
# HINT: You will need to use the 'Data' key from the json response, then transpose the DataFrame.
response_data = requests.get(url)

# %%
data = response_data.json()

# %%
df = pd.DataFrame(data['Data']).transpose()

# %%
df.reset_index(inplace = True)
df
# Out:
#       index      Id                    Url                         ImageUrl  \
# 0        42    4321     /coins/42/overview           /media/35650717/42.jpg
# 1       300  749869    /coins/300/overview          /media/27010595/300.png
# 2       365   33639    /coins/365/overview            /media/352070/365.png
# 3       404   21227    /coins/404/overview  /media/35650851/404-300x300.jpg
# 4       433  926547    /coins/433/overview          /media/34836095/433.png
# ...     ...     ...                    ...                              ...
# 5228    DOT  935731    /coins/dot/overview          /media/37072130/dot.png
# 5229  VIDYA  936339  /coins/vidya/overview        /media/37305405/vidya.png
# 5230   QQQF  936342   /coins/qqqf/overview         /media/37305406/qqqf.png
# 5231  LIBFX  936344  /coins/libfx/overview        /media/37305407/libfx.png
# 5232   LIEN  936346   /coins/lien/overview         /media/37305408/lien.png
#
#      ContentCreatedOn   Name Symbol              CoinName  \
# 0          1427211129     42     42               42 Coin
# 1          1517935016    300    300             300 token
# 2          1480032918    365    365               365Coin
# 3          1466100361    404    404               404Coin
# 4          1541597321    433    433             433 Token
# ...               ...    ...    ...                   ...
# 5228       1593791455    DOT    DOT              Polkadot
# 5229       1598974844  VIDYA  VIDYA                 Vidya
# 5230       1598975290   QQQF   QQQF  Standard Crypto Fund
# 5231       1598975577  LIBFX  LIBFX                 Libfx
# 5232       1598976070   LIEN   LIEN                  lien
#
#                          FullName Algorithm  ... SortOrder Sponsored  \
# 0                    42 Coin (42)    Scrypt  ...        34     False
# 1                 300 token (300)       N/A  ...      2212     False
# 2                   365Coin (365)       X11  ...       916     False
# 3                   404Coin (404)    Scrypt  ...       602     False
# 4                 433 Token (433)       N/A  ...      3505     False
# ...                           ...       ...  ...       ...       ...
# 5228               Polkadot (DOT)       N/A  ...      5535     False
# 5229                Vidya (VIDYA)       N/A  ...      5724     False
# 5230  Standard Crypto Fund (QQQF)       N/A  ...      5726     False
# 5231                Libfx (LIBFX)       N/A  ...      5727     False
# 5232                  lien (LIEN)       N/A  ...      5728     False
#
#                                                Taxonomy  \
# 0     {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...
# 1     {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...
# 2     {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...
# 3     {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...
# 4     {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...
# ...                                                 ...
# 5228  {'Access': 'Permissioned', 'FCA': 'Utility', '...
# 5229  {'Access': 'Permissionless', 'FCA': 'Utility',...
# 5230  {'Access': 'Permissionless', 'FCA': 'Utility',...
# 5231  {'Access': 'Permissionless', 'FCA': 'Utility',...
# 5232  {'Access': 'Permissionless', 'FCA': 'Utility',...
#
#                                                  Rating IsTrading  \
# 0     {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...      True
# 1     {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...      True
# 2     {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...      True
# 3     {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...      True
# 4     {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...     False
# ...                                                 ...       ...
# 5228  {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...      True
# 5229  {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...     False
# 5230  {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...     False
# 5231  {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...     False
# 5232  {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...     False
#
#      TotalCoinsMined BlockNumber NetHashesPerSecond BlockReward BlockTime
# 0                 42      194639                  0           0         0
# 1                300           0                  0           0         0
# 2                NaN         NaN                NaN         NaN       NaN
# 3        1.12364e+06       42082                  0      11.087        60
# 4        1.12423e+08    10776236    221634832754715           2         0
# ...              ...         ...                ...         ...       ...
# 5228      9.8745e+08           0                  0           0         0
# 5229               0           0                  0           4         0
# 5230        50000000           0                  0           0         0
# 5231        35000000           0                  0           0         0
# 5232          0.0001           0                  0           0         0
#
# [5233 rows x 28 columns]

# %%
# Alternatively, use the provided csv file:
from pathlib import Path
file_path = Path("Resources/crypto_data.csv")

# Create a DataFrame
crypto_df = pd.read_csv(file_path)
crypto_df
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# 4        0.000000e+00               0
# ...               ...             ...
# 1247     1.283270e+05         1000000
# 1248     2.149121e+07       100000000
# 1249              NaN       233100000
# 1250              NaN        21000000
# 1251              NaN        40000000
#
# [1252 rows x 7 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
crypto_df = crypto_df[['CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply']]
crypto_df
# Out:
#             CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0            42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1            365Coin       X11       True   PoW/PoS              NaN
# 2            404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3          SixEleven   SHA-256       True       PoW              NaN
# 4                808   SHA-256       True   PoW/PoS     0.000000e+00
# ...              ...       ...        ...       ...              ...
# 1247     BitcoinPlus    Scrypt       True       PoS     1.283270e+05
# 1248      DivotyCoin    Scrypt      False   PoW/PoS     2.149121e+07
# 1249     Giotto Coin    Scrypt      False   PoW/PoS              NaN
# 1250  OpenSourceCoin   SHA-256      False   PoW/PoS              NaN
# 1251       SteamPunk       PoS      False       PoS              NaN
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...              ...
# 1247         1000000
# 1248       100000000
# 1249       233100000
# 1250        21000000
# 1251        40000000
#
# [1252 rows x 6 columns]

# %%
# Keep only cryptocurrencies that are trading
crypto_df = crypto_df[crypto_df['IsTrading']]
crypto_df
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 1         365Coin          X11       True   PoW/PoS              NaN
# 2         404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 3       SixEleven      SHA-256       True       PoW              NaN
# 4             808      SHA-256       True   PoW/PoS     0.000000e+00
# ...           ...          ...        ...       ...              ...
# 1243   Super Zero       Ethash       True       PoW              NaN
# 1244          UOS      SHA-256       True      DPoI              NaN
# 1245       Beldex  CryptoNight       True       PoW     9.802226e+08
# 1246      Horizen     Equihash       True       PoW     7.296538e+06
# 1247  BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...              ...
# 1243      1000000000
# 1244      1000000000
# 1245      1400222610
# 1246        21000000
# 1247         1000000
#
# [1144 rows x 6 columns]

# %%
# Keep only cryptocurrencies with a working algorithm
crypto_df = crypto_df[crypto_df['Algorithm'] != 'N/A']
crypto_df
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 1         365Coin          X11       True   PoW/PoS              NaN
# 2         404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 3       SixEleven      SHA-256       True       PoW              NaN
# 4             808      SHA-256       True   PoW/PoS     0.000000e+00
# ...           ...          ...        ...       ...              ...
# 1243   Super Zero       Ethash       True       PoW              NaN
# 1244          UOS      SHA-256       True      DPoI              NaN
# 1245       Beldex  CryptoNight       True       PoW     9.802226e+08
# 1246      Horizen     Equihash       True       PoW     7.296538e+06
# 1247  BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...              ...
# 1243      1000000000
# 1244      1000000000
# 1245      1400222610
# 1246        21000000
# 1247         1000000
#
# [1144 rows x 6 columns]

# %%
# Remove the "IsTrading" column
crypto_df = crypto_df.drop(['IsTrading'], axis = 1)
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 1         365Coin          X11   PoW/PoS              NaN      2300000000
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 3       SixEleven      SHA-256       PoW              NaN          611000
# 4             808      SHA-256   PoW/PoS     0.000000e+00               0
# ...           ...          ...       ...              ...             ...
# 1243   Super Zero       Ethash       PoW              NaN      1000000000
# 1244          UOS      SHA-256      DPoI              NaN      1000000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [1144 rows x 5 columns]

# %%
# Remove rows with at least 1 null value
crypto_df.dropna(inplace = True)
crypto_df.isnull().sum()
# Out:
# CoinName           0
# Algorithm          0
# ProofType          0
# TotalCoinsMined    0
# TotalCoinSupply    0
# dtype: int64

# %%
crypto_df.dtypes
# Out:
# CoinName            object
# Algorithm           object
# ProofType           object
# TotalCoinsMined    float64
# TotalCoinSupply     object
# dtype: object

# %%
# Remove rows with cryptocurrencies having no coins mined
#coins_df['TotalCoinsMined'] = coins_df['TotalCoinsMined'].astype(float)
crypto_df.drop(crypto_df[crypto_df['TotalCoinsMined'] == 0].index, 
              inplace = True)
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# 7         Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# 8        Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# 1238       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# 1242      Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [533 rows x 5 columns]

# %%
# Drop rows where there are 'N/A' text values
crypto_df.drop(crypto_df[crypto_df.values == 'N/A'].index, inplace = True)
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# 7         Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# 8        Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# 1238       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# 1242      Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [533 rows x 5 columns]

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
coins_name = crypto_df['CoinName'].to_frame()
coins_name
# Out:
#          CoinName
# 0         42 Coin
# 2         404Coin
# 5       EliteCoin
# 7         Bitcoin
# 8        Ethereum
# ...           ...
# 1238       ZEPHYR
# 1242      Gapcoin
# 1245       Beldex
# 1246      Horizen
# 1247  BitcoinPlus
#
# [533 rows x 1 columns]

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
crypto_df.drop('CoinName', axis = 1, inplace = True)
crypto_df
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0          Scrypt   PoW/PoS     4.199995e+01              42
# 2          Scrypt   PoW/PoS     1.055185e+09       532000000
# 5             X13   PoW/PoS     2.927942e+10    314159265359
# 7         SHA-256       PoW     1.792718e+07        21000000
# 8          Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# 1238      SHA-256      DPoS     2.000000e+09      2000000000
# 1242       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245  CryptoNight       PoW     9.802226e+08      1400222610
# 1246     Equihash       PoW     7.296538e+06        21000000
# 1247       Scrypt       PoS     1.283270e+05         1000000
#
# [533 rows x 4 columns]

# %%
# Create dummy variables for text features
X = pd.get_dummies(crypto_df, 
                columns = ['Algorithm', 'ProofType'])
X
# Out:
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 0        4.199995e+01              42                                 0
# 2        1.055185e+09       532000000                                 0
# 5        2.927942e+10    314159265359                                 0
# 7        1.792718e+07        21000000                                 0
# 8        1.076842e+08               0                                 0
# ...               ...             ...                               ...
# 1238     2.000000e+09      2000000000                                 0
# 1242     1.493105e+07       250000000                                 0
# 1245     9.802226e+08      1400222610                                 0
# 1246     7.296538e+06        21000000                                 0
# 1247     1.283270e+05         1000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 0                 0                  0                   0                0
# 2                 0                  0                   0                0
# 5                 0                  0                   0                0
# 7                 0                  0                   0                0
# 8                 0                  0                   0                0
# ...             ...                ...                 ...              ...
# 1238              0                  0                   0                0
# 1242              0                  0                   0                0
# 1245              0                  0                   0                0
# 1246              0                  0                   0                0
# 1247              0                  0                   0                0
#
#       Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  ...  \
# 0                     0                  0              0  ...
# 2                     0                  0              0  ...
# 5                     0                  0              0  ...
# 7                     0                  0              0  ...
# 8                     0                  0              0  ...
# ...                 ...                ...            ...  ...
# 1238                  0                  0              0  ...
# 1242                  0                  0              0  ...
# 1245                  0                  0              0  ...
# 1246                  0                  0              0  ...
# 1247                  0                  0              0  ...
#
#       ProofType_PoW/PoS  ProofType_PoW/PoS   ProofType_PoW/PoW  \
# 0                     1                   0                  0
# 2                     1                   0                  0
# 5                     1                   0                  0
# 7                     0                   0                  0
# 8                     0                   0                  0
# ...                 ...                 ...                ...
# 1238                  0                   0                  0
# 1242                  1                   0                  0
# 1245                  0                   0                  0
# 1246                  0                   0                  0
# 1247                  0                   0                  0
#
#       ProofType_PoW/nPoS  ProofType_Pos  ProofType_Proof of Authority  \
# 0                      0              0                             0
# 2                      0              0                             0
# 5                      0              0                             0
# 7                      0              0                             0
# 8                      0              0                             0
# ...                  ...            ...                           ...
# 1238                   0              0                             0
# 1242                   0              0                             0
# 1245                   0              0                             0
# 1246                   0              0                             0
# 1247                   0              0                             0
#
#       ProofType_Proof of Trust  ProofType_TPoS  \
# 0                            0               0
# 2                            0               0
# 5                            0               0
# 7                            0               0
# 8                            0               0
# ...                        ...             ...
# 1238                         0               0
# 1242                         0               0
# 1245                         0               0
# 1246                         0               0
# 1247                         0               0
#
#       ProofType_Zero-Knowledge Proof  ProofType_dPoW/PoW
# 0                                  0                   0
# 2                                  0                   0
# 5                                  0                   0
# 7                                  0                   0
# 8                                  0                   0
# ...                              ...                 ...
# 1238                               0                   0
# 1242                               0                   0
# 1245                               0                   0
# 1246                               0                   0
# 1247                               0                   0
#
# [533 rows x 100 columns]

# %%
# Standardize data
coins_scaled = StandardScaler().fit_transform(X)
coins_scaled
# Out:
# array([[-0.11674788, -0.15286468, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [-0.09358885, -0.14499604, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [ 0.52587231,  4.4937636 , -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        ...,
#        [-0.09523411, -0.13215444, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [-0.11658774, -0.15255408, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [-0.11674507, -0.15284989, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ]])

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
pca = PCA(n_components = 3)
pca
# Out:
# PCA(n_components=3)

# %%
# Create a DataFrame with the principal components data
coins_pca = pca.fit_transform(coins_scaled)
coins_pca
# Out:
# array([[-0.32285945,  1.03346837, -0.56987899],
#        [-0.30623388,  1.03376921, -0.57033169],
#        [ 2.29618078,  1.64126589, -0.68384559],
#        ...,
#        [ 0.3216167 , -2.32075714,  0.42592452],
#        [-0.19861539, -1.98155194,  0.35226124],
#        [-0.27650507,  0.78154898, -0.28154078]])

# %%
pcs_df = pd.DataFrame(
                data = coins_pca,
                columns = ['PC 1',
                           'PC 2',
                           'PC 3'],
                index = crypto_df.index.to_list())
pcs_df
# Out:
#           PC 1      PC 2      PC 3
# 0    -0.322859  1.033468 -0.569879
# 2    -0.306234  1.033769 -0.570332
# 5     2.296181  1.641266 -0.683846
# 7    -0.151044 -1.309224  0.220048
# 8    -0.139112 -2.090298  0.362069
# ...        ...       ...       ...
# 1238  2.509894  0.623410  0.274921
# 1242 -0.320910  1.033374 -0.569912
# 1245  0.321617 -2.320757  0.425925
# 1246 -0.198615 -1.981552  0.352261
# 1247 -0.276505  0.781549 -0.281541
#
# [533 rows x 3 columns]

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters = i, random_state = 0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {'k': k, 'inertia': inertia}
elbow_df = pd.DataFrame(elbow_data)
elbow_df
# Out:
#     k      inertia
# 0   1  3644.560778
# 1   2  2481.295141
# 2   3  1509.371912
# 3   4   515.128114
# 4   5   314.663636
# 5   6   251.027274
# 6   7   212.801320
# 7   8   172.301384
# 8   9   143.115811
# 9  10   114.906243

# %%
#!pip install -U altair
import altair as alt

# %%
alt.Chart(elbow_df).mark_line().encode(
    x='k',
    y='inertia',
).properties(title='Elbow Curve')
# Out:
# alt.Chart(...)

# %% [markdown]
# Running K-Means with `k=<your best value for k here>`

# %%
# Initialize the K-Means model
model = KMeans(n_clusters = 4, random_state = 0)
# Fit the model
model.fit(pcs_df)
# Predict clusters
predications = model.predict(pcs_df)
# Create a new DataFrame including predicted clusters and cryptocurrencies features
pcs_df['Class'] = model.labels_
pcs_df
# Out:
#           PC 1      PC 2      PC 3  Class
# 0    -0.322859  1.033468 -0.569879      0
# 2    -0.306234  1.033769 -0.570332      0
# 5     2.296181  1.641266 -0.683846      0
# 7    -0.151044 -1.309224  0.220048      1
# 8    -0.139112 -2.090298  0.362069      1
# ...        ...       ...       ...    ...
# 1238  2.509894  0.623410  0.274921      0
# 1242 -0.320910  1.033374 -0.569912      0
# 1245  0.321617 -2.320757  0.425925      1
# 1246 -0.198615 -1.981552  0.352261      1
# 1247 -0.276505  0.781549 -0.281541      0
#
# [533 rows x 4 columns]

# %%
clustered_df = pd.concat([crypto_df, pcs_df, coins_name],
                        join = 'inner', axis = 1)
clustered_df
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply      PC 1  \
# 0          Scrypt   PoW/PoS     4.199995e+01              42 -0.322859
# 2          Scrypt   PoW/PoS     1.055185e+09       532000000 -0.306234
# 5             X13   PoW/PoS     2.927942e+10    314159265359  2.296181
# 7         SHA-256       PoW     1.792718e+07        21000000 -0.151044
# 8          Ethash       PoW     1.076842e+08               0 -0.139112
# ...           ...       ...              ...             ...       ...
# 1238      SHA-256      DPoS     2.000000e+09      2000000000  2.509894
# 1242       Scrypt   PoW/PoS     1.493105e+07       250000000 -0.320910
# 1245  CryptoNight       PoW     9.802226e+08      1400222610  0.321617
# 1246     Equihash       PoW     7.296538e+06        21000000 -0.198615
# 1247       Scrypt       PoS     1.283270e+05         1000000 -0.276505
#
#           PC 2      PC 3  Class     CoinName
# 0     1.033468 -0.569879      0      42 Coin
# 2     1.033769 -0.570332      0      404Coin
# 5     1.641266 -0.683846      0    EliteCoin
# 7    -1.309224  0.220048      1      Bitcoin
# 8    -2.090298  0.362069      1     Ethereum
# ...        ...       ...    ...          ...
# 1238  0.623410  0.274921      0       ZEPHYR
# 1242  1.033374 -0.569912      0      Gapcoin
# 1245 -2.320757  0.425925      1       Beldex
# 1246 -1.981552  0.352261      1      Horizen
# 1247  0.781549 -0.281541      0  BitcoinPlus
#
# [533 rows x 9 columns]

# %% [markdown]
# ### Visualizing Results
#
# #### 3D-Scatter with Clusters

# %%
alt.Chart(clustered_df).mark_circle(size=60).encode(
    x='PC 1',
    y='PC 2',
    color='Class',
    tooltip=['CoinName', 'Algorithm', 'TotalCoinsMined', 'TotalCoinSupply']
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos
df = clustered_df[['CoinName', 'Algorithm', 'ProofType','TotalCoinSupply','TotalCoinsMined', 'Class']]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
    display(df)
# Out:
#                               CoinName               Algorithm  \
# 0                              42 Coin                  Scrypt
# 2                              404Coin                  Scrypt
# 5                            EliteCoin                     X13
# 7                              Bitcoin                 SHA-256
# 8                             Ethereum                  Ethash
# 9                             Litecoin                  Scrypt
# 10                                Dash                     X11
# 11                              Monero          CryptoNight-V7
# 12                    Ethereum Classic                  Ethash
# 13                               ZCash                Equihash
# 14                           Bitshares                 SHA-512
# 15                            DigiByte                Multiple
# 16                         BitcoinDark                 SHA-256
# 19                             PayCoin                 SHA-256
# 20                         ProsperCoin                  Scrypt
# 24                            KoboCoin                     X15
# 27                          Spreadcoin                     X11
# 37                            Argentum                  Scrypt
# 39                         Aurora Coin                  Scrypt
# 42                            BlueCoin                  Scrypt
# 44                          MyriadCoin                Multiple
# 45                            MoonCoin                  Scrypt
# 46                            ZetaCoin                 SHA-256
# 47                             SexCoin                  Scrypt
# 48                             Quatloo                  Scrypt
# 49                          EnergyCoin                  Scrypt
# 50                           QuarkCoin                   Quark
# 51                             Riecoin                 Groestl
# 52                        Digitalcoin                   Scrypt
# 54                              BitBar                  Scrypt
# 61                             Catcoin                  Scrypt
# 62                       CryptoBullion                  Scrypt
# 63                           CannaCoin                  Scrypt
# 73                           CryptCoin                     X11
# 74                          CasinoCoin                  Scrypt
# 76                             Diamond                 Groestl
# 77                               Verge                Multiple
# 80                             DevCoin                 SHA-256
# 81                           EarthCoin                  Scrypt
# 82                            E-Gulden                  Scrypt
# 84                         Einsteinium                  Scrypt
# 85                             Emerald                  Scrypt
# 86                      Exclusive Coin                     PoS
# 94                         FlutterCoin                  Scrypt
# 95                              Franko                  Scrypt
# 98                         FeatherCoin               NeoScrypt
# 99                           GrandCoin                  Scrypt
# 100                         GlobalCoin                  Scrypt
# 101                           GoldCoin                  Scrypt
# 107                        HoboNickels                  Scrypt
# 110                         HyperStake                     X11
# 112                      Infinite Coin                  Scrypt
# 113                             IOCoin                     X11
# 114                             IXcoin                 SHA-256
# 120                         KrugerCoin                  Scrypt
# 122                          LuckyCoin                  Scrypt
# 124                           Litebar                   Scrypt
# 129                            MaxCoin                    SHA3
# 130                           MegaCoin                  Scrypt
# 131                  MediterraneanCoin     HybridScryptHash256
# 133                           MintCoin                  Scrypt
# 135                            MinCoin                  Scrypt
# 137                           MazaCoin                 SHA-256
# 139                      Nautilus Coin                  Scrypt
# 140                            NavCoin                     X13
# 144                          NobleCoin                  Scrypt
# 146                           Namecoin                 SHA-256
# 147                           NyanCoin                  Scrypt
# 148                           OpalCoin                     X13
# 149                          Orbitcoin               NeoScrypt
# 151                            PotCoin                  Scrypt
# 153                        PhoenixCoin                  Scrypt
# 155                           Reddcoin                  Scrypt
# 157                        RonPaulCoin                  Scrypt
# 162                         StableCoin                  Scrypt
# 168                          SmartCoin                  Scrypt
# 174                          SuperCoin                     X11
# 175                           SyncCoin                     X11
# 176                            SysCoin                 SHA-256
# 179                          TeslaCoin                Multiple
# 180                          TigerCoin                 SHA-256
# 181                         TittieCoin                 PHI1612
# 182                            TorCoin                     X11
# 183                          TerraCoin                 SHA-256
# 186                    UnbreakableCoin                 SHA-256
# 187                         Unobtanium                 SHA-256
# 188                            UroCoin                     X11
# 189               UnitaryStatus Dollar                  Scrypt
# 190                          UltraCoin                  Scrypt
# 193                            ViaCoin                  Scrypt
# 195                           VeriCoin                  Scrypt
# 196                           Vertcoin               Lyra2REv2
# 197                          WorldCoin                  Scrypt
# 200                           X11 Coin                     X11
# 202                             Crypti                Multiple
# 203                          JouleCoin                 SHA-256
# 205                        StealthCoin                     X13
# 208                           ZCC Coin                  Scrypt
# 210                           ByteCoin             CryptoNight
# 212                       DigitalNote              CryptoNight
# 214                          BurstCoin               Shabal256
# 215                          StorjCoin            Counterparty
# 218                           MonaCoin                  Scrypt
# 220                            Neutron                 SHA-256
# 224                           FairCoin                 Groestl
# 225                             Gulden                  Scrypt
# 226                           RubyCoin                  Scrypt
# 227                         PesetaCoin                  Scrypt
# 228                               Kore                     X13
# 229                    Wild Beast Coin                  Scrypt
# 231                             Dnotes                  Scrypt
# 232                                Flo                  Scrypt
# 234                          8BIT Coin                  Scrypt
# 235                        Sativa Coin                     X13
# 239                            ArtByte                  Scrypt
# 244                       Folding Coin        Stanford Folding
# 246                              Ucoin                     X11
# 247                             Unitus                Multiple
# 248                     CypherPunkCoin                   QuBit
# 251                           OmniCron                  Scrypt
# 254                           Vtorrent                  Scrypt
# 256                          GreenCoin                  Scrypt
# 263                         Cryptonite                  M7 POW
# 267                         MasterCoin                  Scrypt
# 273                           SoonCoin                 SHA-256
# 276                            1Credit                  Scrypt
# 281                           IslaCoin                     X11
# 286                              Nexus                    SHA3
# 289                          MarsCoin                      X11
# 294                             Crypto                 Lyra2RE
# 301                   Anarchists Prime                 SHA-256
# 302                             Droidz                   QUAIT
# 303                           BowsCoin                     X11
# 307                        Squall Coin                     X11
# 315                          Song Coin                  Scrypt
# 320                            BitZeny                  Scrypt
# 321                            Diggits                  Scrypt
# 322                            Expanse                  Ethash
# 324                             Paycon                     X13
# 325                            Siacoin                 Blake2b
# 327                           Emercoin                 SHA-256
# 330                      EverGreenCoin                     X15
# 331                           MindCoin                     X11
# 332                             I0coin                 SHA-256
# 333                             Decred                BLAKE256
# 335                      Revolution VR                  Scrypt
# 336                           HOdlcoin  1GB AES Pattern Search
# 337                            EDRCoin                 SHA-256
# 338                            Hitcoin                     X11
# 339                        Gamecredits                  Scrypt
# 341                          DubaiCoin                 SHA-256
# 343                      CarpeDiemCoin                 SHA-256
# 345                           PWR Coin                   NIST5
# 347                        BillaryCoin                  Scrypt
# 352                           GPU Coin                  Scrypt
# 355                            Adzcoin                     X11
# 358                           SoilCoin                  Dagger
# 359                             YoCoin                  Scrypt
# 362                            SibCoin                 X11GOST
# 363                         EuropeCoin                     X11
# 369                           ZeitCoin                  Scrypt
# 371                          SwingCoin                 SHA-256
# 372                   SafeExchangeCoin                  Scrypt
# 373                     Nebuchadnezzar                     PoS
# 375                             Francs                  Scrypt
# 385                        BolivarCoin                     X11
# 391                           Ratecoin                     X11
# 397                             Revenu                 SHA-256
# 403                          Clockcoin                 SHA-256
# 404                         VIP Tokens                   NIST5
# 413                            BitSend                     X11
# 420                               Omni                  Scrypt
# 422                        Let it Ride                 POS 3.0
# 426                          PutinCoin                  Scrypt
# 428                          iBankCoin                  Scrypt
# 431                     Frankywillcoin                  Scrypt
# 436                          MudraCoin                     X13
# 437                          PizzaCoin                     X11
# 438                      Lutetium Coin                     X11
# 440                             Komodo                Equihash
# 441                         GoldBlocks                     X11
# 446                         CarterCoin                  Scrypt
# 452                              Karbo             CryptoNight
# 454                          BitTokens                 SHA-256
# 455                          ZayedCoin                 SHA-256
# 456                        MustangCoin                     X11
# 458                           ZoneCoin                  Scrypt
# 459                  Circuits of Value                Multiple
# 462                           RootCoin                  Scrypt
# 463                           DopeCoin                  Scrypt
# 472                        BitCurrency                  Scrypt
# 475                         DollarCoin                 SHA-256
# 476                           Swiscoin                  Scrypt
# 478                           Shilling                  Scrypt
# 479                           BuzzCoin                SHA-256D
# 482                              Opair                     PoS
# 483                            PesoBit                  Scrypt
# 491                     Halloween Coin                     X11
# 504                              ZCoin                  Lyra2Z
# 509                         CoffeeCoin                     PoS
# 516                          RoyalCoin                     X13
# 522                       GanjaCoin V2                     X14
# 523                             TeamUP                     PoS
# 525                           LanaCoin                SHA-256D
# 526                         Elementrem                  Ethash
# 534                           ZClassic                Equihash
# 539                                ARK                    DPoS
# 543                         InsaneCoin                     X11
# 548                           KiloCoin                  Scrypt
# 555                          ArtexCoin                     X11
# 560                          EmberCoin                     X13
# 563                          XenixCoin                     X11
# 565                           FreeCoin                     PoS
# 567                            PLNCoin                  Scrypt
# 570                       AquariusCoin                  Scrypt
# 571                            Kurrent                     X11
# 572                            Creatio                     PoS
# 573                           Eternity                     X11
# 576                           Eurocoin                 SHA-256
# 578                        BitcoinFast                  Scrypt
# 580                           Stakenet                     X11
# 581                    BitConnect Coin                  Scrypt
# 585                          MoneyCoin                  Scrypt
# 592                             Enigma                     X11
# 593             Cannabis Industry Coin             CryptoNight
# 599                         Russiacoin                  Scrypt
# 600                          PandaCoin                  Scrypt
# 605                          GameUnits                  Scrypt
# 606                           GAKHcoin                  Scrypt
# 608                            Allsafe                   Quark
# 609                          LiteCreed                   QuBit
# 622                         OsmiumCoin                  Scrypt
# 623                         Bikercoins             CryptoNight
# 626                           HexxCoin                 Lyra2RE
# 639              Klingon Empire Darsek                  Scrypt
# 640                 Internet of People                 SHA-256
# 642                           KushCoin                     X11
# 652                         Printerium                  Scrypt
# 653                            PacCoin                     X11
# 654                            Impeach                  Scrypt
# 662                            Citadel          CryptoNight-V7
# 663                         Zilbercoin                  Scrypt
# 664                          FirstCoin                  Scrypt
# 674                         BeaverCoin                  Scrypt
# 675                           FindCoin                     X13
# 679                          VaultCoin                     X11
# 681                               Zero                Equihash
# 682                           OpenChat                  Scrypt
# 683                       Canada eCoin                  Scrypt
# 684                               Zoin                 Lyra2RE
# 694                          RenosCoin                  Scrypt
# 695                          DubaiCoin        Dagger-Hashimoto
# 696                      VirtacoinPlus                     X11
# 698                            TajCoin                 Blake2S
# 699                             Impact                     X11
# 703                            EB3coin                  Scrypt
# 711                              Atmos                     PoS
# 712                          HappyCoin                     X11
# 713                           Coinonat                   NIST5
# 714                         MacronCoin                     PoS
# 715                         Condensate                     X11
# 717           Independent Money System                  Scrypt
# 718                          ArgusCoin                  Scrypt
# 719                           LomoCoin                  Scrypt
# 721                        ProCurrency                 SHA-256
# 722                        GoldReserve                     X11
# 723                         BenjiRolls                  Scrypt
# 725                         GrowthCoin                  Scrypt
# 726                             ILCoin                 SHA-256
# 728                             Phreak                     PoS
# 732                         Degas Coin                  Scrypt
# 737                         HTML5 Coin                     X15
# 739               Ultimate Secure Cash                 SHA-256
# 742                         EquiTrader                  Scrypt
# 745                               QTUM                 POS 3.0
# 747           Quantum Resistant Ledger          CryptoNight-V7
# 748                             Espers                     536
# 749                            Dynamic                 Argon2d
# 750                               Nano                 Blake2b
# 751                           ChanCoin              Cloverhash
# 752                        Dinastycoin             CryptoNight
# 753                           Denarius                   NIST5
# 754                       DigitalPrice                     X11
# 755                  Virta Unique Coin                   NIST5
# 756                     Bitcoin Planet                   Skein
# 757                              Unify                  Scrypt
# 758                           BritCoin                     X13
# 759                         SocialCoin                  Scrypt
# 761                         ArcticCoin                     X11
# 764                                DAS                     X11
# 765                              Linda                  Scrypt
# 766                         LeviarCoin             CryptoNight
# 767                          DeepOnion                     X13
# 768                            Bitcore             Time Travel
# 769                           gCn Coin                  Scrypt
# 770                          SmartCash                  Keccak
# 771                           Signatum     SkunkHash v2 Raptor
# 772                               Onix                     X11
# 774                              Cream                   Skein
# 775                       Bitcoin Cash                 SHA-256
# 777                            Monoeci                     X11
# 779                          Draftcoin                  Scrypt
# 780                            Vechain   VeChainThor Authority
# 781                       Sojourn Coin                  Scrypt
# 782                          Stakecoin                     PoS
# 783                        NewYorkCoin                  Scrypt
# 785                           FrazCoin                  Scrypt
# 786                          Kronecoin                  Scrypt
# 787                             AdCoin                  Scrypt
# 788                               Linx                  Scrypt
# 789                          CoinonatX                  Scrypt
# 791                      Ethereum Dark                  Scrypt
# 792                           Sumokoin             CryptoNight
# 793                           Obsidian                 SHA-512
# 794                            Cardano               Ouroboros
# 795                          Regalcoin                     X11
# 796                           BitcoinZ                Equihash
# 798                         TrezarCoin               NeoScrypt
# 799                           Elements                     X11
# 800                      TerraNovaCoin                  Scrypt
# 801                          VIVO Coin               NeoScrypt
# 803                              Rupee               Lyra2REv2
# 804                       Bitcoin Gold                Equihash
# 805                          WomenCoin                  Scrypt
# 806                   Theresa May Coin                 SHA-256
# 808                           NamoCoin                   NIST5
# 809                            LUXCoin                 PHI1612
# 810                               Pirl                  Dagger
# 811                               Xios                  Scrypt
# 812                       Bitcloud 2.0                   Quark
# 813                             eBoost                  Scrypt
# 814                            KekCoin                 POS 2.0
# 815                      BlackholeCoin                  Scrypt
# 819                 Infinity Economics                 SHA-256
# 822                               Pura                     X11
# 823                             Innova               NeoScrypt
# 827                            Ellaism                  Ethash
# 830                             GoByte               NeoScrypt
# 835                             Magnet                     X11
# 836                         Lamden Tau                    DPoS
# 837                            Electra                   NIST5
# 838                    Bitcoin Diamond                     X13
# 840                             SHIELD                Multiple
# 844                   Cash & Back Coin                  Scrypt
# 845                          UltraNote             CryptoNight
# 850                            BitCoal             CryptoNight
# 851                           DaxxCoin                  Ethash
# 852                            Bulwark                   NIST5
# 855                           Kalkulus                   Quark
# 856                                AC3                     X11
# 858                            Lethean          CryptoNight-V7
# 859                         GermanCoin                  Scrypt
# 860                     LiteCoin Ultra                  Scrypt
# 862                        PopularCoin                  Scrypt
# 863                           PhantomX                     X11
# 866                             Photon                BLAKE256
# 867                              Sucre                     X11
# 873                          SparksPay               NeoScrypt
# 875                           Digiwage                   Quark
# 876                            GunCoin               NeoScrypt
# 878                          IrishCoin                  Scrypt
# 879                          Trollcoin                  Scrypt
# 880                      Litecoin Plus                  Scrypt
# 882                     Monkey Project                     X11
# 887                       Pioneer Coin                     X11
# 888                      UnitedBitcoin                 SHA-256
# 889                          Interzone                     C11
# 897                           TokenPay                 POS 3.0
# 899   1717 Masonic Commemorative Token                  Ethash
# 901                        My Big Coin                  Scrypt
# 903                         TurtleCoin             CryptoNight
# 905                            MUNcoin               SkunkHash
# 906              Unified Society USDEX                  Scrypt
# 909                        Niobio Cash             CryptoNight
# 918                         ShareChain                  Scrypt
# 920                         Travelflex                  Dagger
# 921                              KREDS               Lyra2REv2
# 923                         Tokyo Coin                     X13
# 924                           BiblePay      Proof-of-BibleHash
# 925                       LitecoinCash          SHA-256 + Hive
# 926                            BitFlip                  Scrypt
# 927                          LottoCoin                  Scrypt
# 935            Crypto Improvement Fund                     X11
# 936                            Stipend                     C11
# 937                        Poa Network      Proof-of-Authority
# 938                              Pushi                     X11
# 940                           Ellerium                   XEVAN
# 941                              Velox                  Scrypt
# 942                           Ontology                    VBFT
# 943                   Callisto Network                  Ethash
# 946                            BitTube             CryptoNight
# 948                           Poseidon                  Scrypt
# 952                       Aidos Kuneen                   IMesh
# 958                           Bitspace                   NIST5
# 963                           Briacoin                  Scrypt
# 964                           Ignition                  Scrypt
# 966                          Bitrolium                Equihash
# 968                          MedicCoin                  Scrypt
# 970                    Alpenschillling                  Lyra2Z
# 972                      Bitcoin Green          Green Protocol
# 973                       Deviant Coin                     PoS
# 974                            Abjcoin                  Scrypt
# 978                              Semux     Semux BFT consensus
# 981                         FuturoCoin                     X11
# 982                            Carebit                   Quark
# 983                            Zealium                     PoS
# 984                     Monero Classic             CryptoNight
# 987                             Proton                    X16R
# 989                          iDealCash                  Scrypt
# 990                           Jumpcoin                   NIST5
# 991                            Infinex                 Lyra2RE
# 992                  Bitcoin Incognito                   XEVAN
# 993                              KEYCO                  Tribus
# 995                      HollyWoodCoin                  Scrypt
# 996                            GINcoin                  Lyra2Z
# 1001                        PlatinCoin             CryptoNight
# 1005                              Loki       CryptoNight Heavy
# 1006                       Newton Coin             CryptoNight
# 1009                         Swisscoin                  Scrypt
# 1013                             Xt3ch                  Scrypt
# 1014                          MassGrid    Jump Consistent Hash
# 1015                            TheVig                SHA-256D
# 1016                         PluraCoin             CryptoNight
# 1017                        EmaratCoin                  Scrypt
# 1021                            Dekado                     X15
# 1022                              Lynx                  Scrypt
# 1023                    Poseidon Quark                   Quark
# 1026                  BitcoinWSpectrum                 SHA-256
# 1029                              Muse                    DPoS
# 1030                            Motion                    X16R
# 1031                       PlusOneCoin                 HMQ1725
# 1032                               Axe                     X11
# 1034                        Trivechain                    X16R
# 1035                            Dystem                   Quark
# 1036                             Giant                   Quark
# 1037                        Peony Coin                  Scrypt
# 1039                     Absolute Coin               Lyra2REv2
# 1040                             Vitae                   Quark
# 1044                           HexCoin                  Scrypt
# 1046                            TPCash                  Scrypt
# 1048                          Webchain          CryptoNight-V7
# 1049                               Ryo         Cryptonight-GPU
# 1051                        Urals Coin                   XEVAN
# 1052                        Qwertycoin       CryptoNight Heavy
# 1054                            ARENON                     X11
# 1056                              EUNO                     X11
# 1057                           MMOCoin                  Scrypt
# 1059                             Ketan                     PoS
# 1063                       Project Pai                 SHA-256
# 1065                              XDNA                  Keccak
# 1066                             PAXEX                     X11
# 1068                             Azart                     X11
# 1071                      ThunderStake                  Scrypt
# 1074                             Kcash                 SHA-512
# 1075                           Xchange                    X16R
# 1076                 Acute Angle Cloud               ECC 256K1
# 1086                       CrypticCoin                Equihash
# 1087                       Bettex coin                   XEVAN
# 1091                          Actinium                  Lyra2Z
# 1097                        Bitcoin SV                 SHA-256
# 1101                          BitMoney                   XEVAN
# 1104             Junson Ming Chan Coin                     X11
# 1105                        FREDEnergy             CryptoNight
# 1111                          HerbCoin                   Quark
# 1114                Universal Molecule                   Blake
# 1115                           Lithium                   Blake
# 1119                        PirateCash                Equihash
# 1120                            Exosis                  Exosis
# 1121                       Block-Logic                  Scrypt
# 1123                             Oduwa                  Scrypt
# 1124                              Beam                Equihash
# 1125                           Galilel                   Quark
# 1127                         Bithereum                Equihash
# 1130                     Crypto Sports                   Quark
# 1131                            Credit                  Scrypt
# 1136                             SLICE                   QuBit
# 1137                     Dash Platinum                     X11
# 1138                         Nasdacoin                  Scrypt
# 1140                       Beetle Coin                   XEVAN
# 1141                        Titan Coin                SHA-256D
# 1142                             Award                     X11
# 1144                             BLAST                 SHA-256
# 1147                   Bitcoin Rhodium                     X13
# 1148                       GlobalToken                 SHA-256
# 1149                       Insane Coin                     X11
# 1151                              ALAX                    DPoS
# 1155                          LiteDoge                  Scrypt
# 1157                         SolarCoin                  Scrypt
# 1158                         TruckCoin                     X11
# 1159                          UFO Coin               NeoScrypt
# 1161                        OrangeCoin                  Scrypt
# 1163                         BlakeCoin                   Blake
# 1164                       BitstarCoin                  Scrypt
# 1165                          NeosCoin                 SHA-256
# 1166                         HyperCoin                  Scrypt
# 1167                          PinkCoin                     X11
# 1170                     Crypto Escudo                  Scrypt
# 1172                         AudioCoin                  Scrypt
# 1175                          IncaKoin                 SHA-256
# 1176                        Piggy Coin                     X11
# 1177                        Crown Coin                 SHA-256
# 1178                          Genstake                  Scrypt
# 1181                        SmileyCoin                  Scrypt
# 1185                        XiaoMiCoin                  Scrypt
# 1186                       Groestlcoin                 Groestl
# 1187                         CapriCoin                     X11
# 1188                          ClubCoin                  Scrypt
# 1189                            Radium                     PoS
# 1190                              Bata                  Scrypt
# 1191                           Pakcoin                  Scrypt
# 1192                        Creditbit                      X11
# 1193                            OKCash                 SHA-256
# 1194                              Lisk                    DPoS
# 1195                            HiCoin                  Scrypt
# 1163                   PoW         7000000000     2.335679e+07      1
# 1164               PoW/PoS           54256119     2.057653e+07      0
# 1165                   PoS           21000000     4.392258e+06      0
# 1166               PoW/PoS                  0     9.631200e+06      0
# 1167               PoW/PoS          500000000     4.363536e+08      0
# 1170                   PoW         1000000000     7.802107e+08      1
# 1172               PoW/PoS        10500000000     9.807325e+08      0
# 1175               PoW/PoS          190000000     1.793973e+10      0
# 1176               PoW/PoS         1000000000     4.942407e+08      0
# 1177                   PoW           42000000     2.298693e+07      1
# 1178               PoW/PoS           15000000     6.000000e+07      0
# 1181                   PoW        50000000000     2.958399e+10      1
# 1185               PoW/PoS          400000000     4.043165e+08      0
# 1186                   PoW          105000000     7.329820e+07      1
# 1187               PoW/PoS          208000000     2.013643e+08      0
# 1188               PoW/PoS          160000000     1.036219e+08      0
# 1189                   PoS            9000000     3.821246e+06      0
# 1190                   PoW            5000000     5.052556e+06      1
# 1191                   PoW          182000000     6.968446e+07      1
# 1192        Proof of Trust           16504333     1.690102e+07      0
# 1193               PoW/PoS          105000000     7.467606e+07      0
# 1194                  DPoS          159918400     1.200121e+08      0
# 1195                   PoS        10008835635     1.000024e+10      0
# 1196               PoW/PoS          300000000     2.520056e+08      0
# 1198               PoW/PoS           60168145     1.120385e+06      0
# 1200                  DPoC         5000000000    -5.917978e+09      3
# 1201                   PoW            2800000     3.332922e+06      1
# 1202               PoW/PoS             120000     1.407778e+05      0
# 1204                   PoW         2100000000     1.000000e+08      1
# 1211                  DPoS                  0     1.020545e+09      0
# 1213                   PoW           24487944     2.448794e+07      1
# 1214                  DPoS                  0     1.122382e+09      0
# 1226                   PoS         1000000000     1.000000e+09      0
# 1230                  LPoS          100000000     1.000000e+08      3
# 1231                   PoS            8634140     9.283138e+06      0
# 1234                  DPoS       990000000000     9.899887e+11      2
# 1237              PoS/LPoS         1000000000     1.000000e+09      0
# 1238                  DPoS         2000000000     2.000000e+09      0
# 1242               PoW/PoS          250000000     1.493105e+07      0
# 1245                   PoW         1400222610     9.802226e+08      1
# 1246                   PoW           21000000     7.296538e+06      1
# 1247                   PoS            1000000     1.283270e+05      0

# %%
# Print the total number of tradable cryptocurrencies
print(f"The total number of tradeble cryptocurrencies: \
      {clustered_df['TotalCoinSupply'].astype('float').sum()}")
# Out:
# The total number of tradeble cryptocurrencies:       5508664273302.22

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
clustered_df['TotalCoinsMined_s'] = StandardScaler().fit_transform(clustered_df[['TotalCoinsMined']])
clustered_df['TotalCoinSupply_s'] = StandardScaler().fit_transform(clustered_df[['TotalCoinSupply']])

# %%
alt.Chart(clustered_df).mark_circle(size=60).encode(
    x='TotalCoinsMined_s',
    y='TotalCoinSupply_s',
    tooltip=['CoinName', 'TotalCoinsMined', 'TotalCoinSupply'],
    color=alt.Color('Class',
                   scale=alt.Scale(range=['red', 'green']))
).interactive()
# Out:
# alt.Chart(...)
